# %%
from datetime import datetime, timedelta
import pandas_datareader.data as reader
import pandas as pd
import yfinance as yf
import numpy as np
from dateutil.relativedelta import relativedelta

# %%
import requests

url = "https://finance.yahoo.com/quote/%5EBVSP/components?p=%5EBVSP"

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)
table = pd.read_html(r.text)[0]
tickers = table["Symbol"].tolist()
tickers
# Out:
# ['RADL3.SA',
#  'TIMP3.SA',
#  'JBSS3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'CCRO3.SA',
#  'UGPA3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'KLBN11.SA',
#  'BRML3.SA',
#  'SBSP3.SA',
#  'ITSA4.SA',
#  'MULT3.SA',
#  'BBSE3.SA',
#  'LREN3.SA',
#  'ENBR3.SA',
#  'ECOR3.SA',
#  'USIM5.SA',
#  'VALE5.SA',
#  'PCAR4.SA',
#  'BRKM5.SA',
#  'EQTL3.SA',
#  'CMIG4.SA',
#  'TBLE3.SA',
#  'LAME4.SA',
#  'OIBR4.SA',
#  '656690',
#  'VIVT4.SA']

# %%
del tickers[28]

# %%
start_day = (datetime.today() - timedelta(days=3650)).strftime('%Y-%m-%d')
end_day = datetime.today().strftime('%Y-%m-%d')
df = yf.download(tickers_,
                start = start_day,
                end = end_day)["Adj Close"]
print("Data início: ",start_day, "\nData fim: ", end_day)
# Out:
# [*********************100%***********************]  84 of 84 completed
# Data início:  2011-09-04
# Data fim:  2021-09-01

# %%
df
# Out:
#              ABEV3.SA   AMER3.SA   ASAI3.SA   AZUL4.SA   B3SA3.SA   BBAS3.SA  \
# Date
# 2011-09-05   6.283900  13.670113        NaN        NaN   2.137134  14.139855
# 2011-09-06   6.282470  14.045371        NaN        NaN   2.123464  14.373052
# 2011-09-08   6.283900  14.545715        NaN        NaN   2.203208  14.691035
# 2011-09-09   6.283900  13.625440        NaN        NaN   2.098402  14.102757
# 2011-09-12   6.325315  14.447434        NaN        NaN   2.050555  13.832466
# ...               ...        ...        ...        ...        ...        ...
# 2021-08-26  17.110001  43.230000  17.370001  38.799999  13.660000  30.070000
# 2021-08-27  17.040001  42.060001  17.400000  39.169998  13.940000  30.530001
# 2021-08-30  17.180000  43.189999  17.160000  37.889999  13.700000  30.240000
# 2021-08-31  16.950001  41.480000  16.990000  37.730000  13.970000  30.430000
# 2021-09-01        NaN        NaN        NaN        NaN        NaN        NaN
#
#              BBDC3.SA   BBDC4.SA   BBSE3.SA  BEEF3.SA  ...  TAEE11.SA  \
# Date                                                   ...
# 2011-09-05   6.129167   8.127051        NaN  4.357640  ...   4.481129
# 2011-09-06   6.338085   8.436730        NaN  4.425199  ...   4.481129
# 2011-09-08   6.429485   8.552500        NaN  4.518095  ...   4.481129
# 2011-09-09   6.184008   8.300701        NaN  4.475870  ...   4.490378
# 2011-09-12   6.092605   8.158890        NaN  4.568765  ...   4.466593
# ...               ...        ...        ...       ...  ...        ...
# 2021-08-26  19.690001  22.969999  19.620001  8.280000  ...  38.139999
# 2021-08-27  19.940001  23.270000  19.730000  8.350000  ...  38.040001
# 2021-08-30  19.770000  23.020000  19.290001  8.440000  ...  38.200001
# 2021-08-31  19.940001  23.150000  19.059999  8.360000  ...  37.910000
# 2021-09-01        NaN        NaN        NaN       NaN  ...        NaN
#
#              TIMS3.SA   TOTS3.SA   UGPA3.SA   USIM5.SA    VALE3.SA   VIIA3.SA  \
# Date
# 2011-09-05   7.147268   7.516735  12.182020  10.064800   28.017277   5.024304
# 2011-09-06   7.267726   7.727225  12.447809  10.503959   28.804863        NaN
# 2011-09-08   7.532738   8.214675  12.912940  10.710094   29.437517   5.024304
# 2011-09-09   7.331971   8.189753  12.625003  10.710094   28.985620   4.907459
# 2011-09-12   7.283788   8.250683  12.505397  10.486034   29.153473   4.907459
# ...               ...        ...        ...        ...         ...        ...
# 2021-08-26  12.220000  38.950001  14.630000  16.293539   98.230003  10.890000
# 2021-08-27  12.220000  39.480000  14.660000  17.403608  100.690002  10.870000
# 2021-08-30  12.220000  39.889999  14.610000  17.535311  100.050003  10.760000
# 2021-08-31  12.380000  39.209999  14.390000  17.394201   98.680000  10.390000
# 2021-09-01        NaN        NaN        NaN        NaN         NaN        NaN
#
#              VIVT3.SA   WEGE3.SA   YDUQ3.SA
# Date
# 2011-09-05  21.139999   2.114075   4.301144
# 2011-09-06  21.598524   2.163604   4.266616
# 2011-09-08  21.960506   2.181725   4.204960
# 2011-09-09  21.719175   2.139443   4.246886
# 2011-09-12  21.767447   2.163604   4.118641
# ...               ...        ...        ...
# 2021-08-26  43.139999  36.770000  27.940001
# 2021-08-27  43.209999  36.900002  27.389999
# 2021-08-30  43.369999  36.680000  26.360001
# 2021-08-31  43.470001  35.500000  25.590000
# 2021-09-01        NaN        NaN        NaN
#
# [2479 rows x 84 columns]

# %%
df.index = pd.to_datetime(df.index)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.title("Adj. Close Price")
plt.xlabel("Date")
plt.ylabel("US$ Price")
plt.plot(df)
plt.legend(df.columns,loc='upper right')
plt.show()

# %%
mtl_ret = df.pct_change().resample('M').agg(lambda x: (x+1).prod() - 1)

# %%
mtl_ret
# Out:
#             ABEV3.SA  AMER3.SA  ASAI3.SA  AZUL4.SA  B3SA3.SA  BBAS3.SA  \
# Date
# 2011-09-30  0.045227 -0.039216  0.000000  0.000000 -0.062900 -0.058531
# 2011-10-31  0.010242 -0.002721  0.000000  0.000000  0.191126  0.042674
# 2011-11-30  0.069888 -0.307640  0.000000  0.000000 -0.045556 -0.060868
# 2011-12-31  0.100807 -0.113301  0.000000  0.000000 -0.008097 -0.008792
# 2012-01-31 -0.047619  0.157778  0.000000  0.000000  0.121429  0.147257
# ...              ...       ...       ...       ...       ...       ...
# 2021-05-31  0.201473 -0.112448  0.105823  0.116883  0.021748  0.144228
# 2021-06-30 -0.049025  0.108954 -0.032532  0.020698 -0.028815 -0.036020
# 2021-07-31 -0.025190 -0.258980  0.001618 -0.113693 -0.093341 -0.015562
# 2021-08-31  0.018630 -0.155193 -0.019959 -0.030077 -0.083934 -0.026631
# 2021-09-30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             BBDC3.SA  BBDC4.SA  BBSE3.SA  BEEF3.SA  ...  TAEE11.SA  TIMS3.SA  \
# Date                                                ...
# 2011-09-30 -0.022583 -0.013177  0.000000 -0.044574  ...   0.002359 -0.022472
# 2011-10-31  0.090512  0.131969  0.000000  0.030426  ...   0.000294  0.034483
# 2011-11-30 -0.005419 -0.054417  0.000000 -0.055118  ...   0.050000 -0.061111
# 2011-12-31  0.042123  0.057809  0.000000  0.104167  ...   0.042017  0.093491
# 2012-01-31  0.026291  0.021621  0.000000 -0.005660  ...   0.126344  0.049784
# ...              ...       ...       ...       ...  ...        ...       ...
# 2021-05-31  0.106848  0.111131  0.047918  0.023760  ...  -0.002756 -0.001641
# 2021-06-30 -0.043035 -0.027642 -0.012820 -0.054490  ...  -0.047496 -0.041647
# 2021-07-31 -0.033042 -0.036849 -0.074892 -0.042689  ...   0.030623 -0.018213
# 2021-08-31 -0.033582 -0.044618 -0.086160 -0.068005  ...  -0.003155  0.093640
# 2021-09-30  0.000000  0.000000  0.000000  0.000000  ...   0.000000  0.000000
#
#             TOTS3.SA  UGPA3.SA  USIM5.SA  VALE3.SA  VIIA3.SA  VIVT3.SA  \
# Date
# 2011-09-30  0.179071  0.072727 -0.063223 -0.017281 -0.139070  0.002055
# 2011-10-31 -0.121875  0.037288  0.121673  0.039838 -0.027553  0.062829
# 2011-11-30  0.160143  0.039869 -0.122034 -0.047129 -0.144444 -0.015486
# 2011-12-31  0.027178  0.005971 -0.020270 -0.052821  0.006493  0.073932
# 2012-01-31 -0.096813  0.104342  0.154680  0.133080  0.122581 -0.077737
# ...              ...       ...       ...       ...       ...       ...
# 2021-05-31  0.108360 -0.085741 -0.115138  0.052834  0.097210  0.027098
# 2021-06-30  0.092254 -0.047150 -0.038268  0.006155  0.216487 -0.049774
# 2021-07-31 -0.060823 -0.038608  0.076963 -0.039647 -0.202660 -0.009996
# 2021-08-31  0.111588 -0.175355 -0.101118 -0.092681 -0.174742  0.054841
# 2021-09-30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             WEGE3.SA  YDUQ3.SA
# Date
# 2011-09-30  0.073295 -0.053899
# 2011-10-31  0.031017  0.218182
# 2011-11-30 -0.071577 -0.094527
# 2011-12-31  0.053944 -0.011539
# 2012-01-31  0.037274  0.104503
# ...              ...       ...
# 2021-05-31 -0.024564  0.124402
# 2021-06-30 -0.012866 -0.001824
# 2021-07-31  0.059958 -0.139464
# 2021-08-31 -0.001458 -0.094480
# 2021-09-30  0.000000  0.000000
#
# [121 rows x 84 columns]

# %%
past11 = (mtl_ret+1).rolling(12).apply(np.prod)-1
past11
# Out:
#             ABEV3.SA  AMER3.SA  ASAI3.SA  AZUL4.SA  B3SA3.SA  BBAS3.SA  \
# Date
# 2011-09-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-10-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-11-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2021-05-31  0.483367 -0.345645  0.257779  2.011205  0.200406  0.151041
# 2021-06-30  0.245039 -0.378944  0.216861  1.182496 -0.036070  0.064369
# 2021-07-31  0.234631 -0.588502  0.218829  0.915313 -0.243097  0.003185
# 2021-08-31  0.420072 -0.629940  0.194503  0.698784 -0.251912 -0.009188
# 2021-09-30  0.394026 -0.539009  0.194503  0.547580 -0.211174  0.088657
#
#             BBDC3.SA  BBDC4.SA  BBSE3.SA  BEEF3.SA  ...  TAEE11.SA  TIMS3.SA  \
# Date                                                ...
# 2011-09-30       NaN       NaN       NaN       NaN  ...        NaN       NaN
# 2011-10-31       NaN       NaN       NaN       NaN  ...        NaN       NaN
# 2011-11-30       NaN       NaN       NaN       NaN  ...        NaN       NaN
# 2011-12-31       NaN       NaN       NaN       NaN  ...        NaN       NaN
# 2012-01-31       NaN       NaN       NaN       NaN  ...        NaN       NaN
# ...              ...       ...       ...       ...  ...        ...       ...
# 2021-05-31  0.451418  0.578671 -0.029374 -0.185608  ...   0.562065 -0.076424
# 2021-06-30  0.302753  0.403914 -0.111740 -0.215931  ...   0.502506 -0.151040
# 2021-07-31  0.151118  0.246214 -0.194798 -0.273169  ...   0.518646 -0.248529
# 2021-08-31  0.210829  0.287101 -0.247199 -0.297240  ...   0.511462 -0.096093
# 2021-09-30  0.277570  0.374061 -0.181751 -0.216428  ...   0.528220 -0.008886
#
#             TOTS3.SA  UGPA3.SA  USIM5.SA  VALE3.SA  VIIA3.SA  VIVT3.SA  \
# Date
# 2011-09-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-10-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-11-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2021-05-31  0.729732  0.139272  2.248805  1.357831  0.046774  0.016233
# 2021-06-30  0.641208  0.011137  1.643130  1.248466  0.031352 -0.065872
# 2021-07-31  0.381457 -0.056643  1.545442  0.988952 -0.355020 -0.157199
# 2021-08-31  0.370778 -0.242074  0.832696  0.835759 -0.493171 -0.036557
# 2021-09-30  0.459803 -0.235388  0.854623  0.779091 -0.401153  0.050754
#
#             WEGE3.SA  YDUQ3.SA
# Date
# 2011-09-30       NaN       NaN
# 2011-10-31       NaN       NaN
# 2011-11-30       NaN       NaN
# 2011-12-31       NaN       NaN
# 2012-01-31       NaN       NaN
# ...              ...       ...
# 2021-05-31  0.647004  0.173632
# 2021-06-30  0.342734 -0.008497
# 2021-07-31  0.067459 -0.152818
# 2021-08-31  0.110934 -0.035310
# 2021-09-30  0.092086 -0.051500
#
# [121 rows x 84 columns]

# %%
def momentum(i):
    end_measurement = past11.index[i-1]
    ret_12 = past11.loc[end_measurement]
    ret_12 = ret_12.reset_index()
    ret_12['decile'] = pd.qcut(ret_12.iloc[:,1], 10, labels=False, duplicates='drop')
    winners = ret_12[ret_12.decile == 9]
    loosers = ret_12[ret_12.decile == 0]
    winnerret = mtl_ret.loc[past11.index[i], mtl_ret.columns.isin(winners['index'])]
    looserret = mtl_ret.loc[past11.index[i], mtl_ret.columns.isin(loosers['index'])]
    Momentumprofit = winnerret.mean() - looserret.mean()
    return Momentumprofit

# %%
profits = []
dates = []
for i in range(120):
    profits.append(momentum(i))
    dates.append(past11.index[i])

# %%
bvsp = yf.download('^BVSP',
                start = start_day,
                end = end_day)["Adj Close"]
print("Data início: ",start_day, "\nData fim: ", end_day)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data início:  2011-09-04
# Data fim:  2021-09-01

# %%
bvsp_ret = bvsp.pct_change().resample('M').agg(lambda x: (x+1).prod() - 1)
# Out:
# 120

# %%
frame = pd.DataFrame()
frame["Model"] = profits
frame["BVSP"] = bvsp_ret.values
frame["excess"] = frame.iloc[:,0] - frame.iloc[:,1]
frame["outperformed"] = ["Yes" if i>0 else "No" for i in frame.excess]

# %%
frame[frame.outperformed == "Yes"].shape
# Out:
# (55, 4)

# %%
frame[frame.outperformed == "No"].shape
# Out:
# (65, 4)

# %%
plt.style.use("dark_background")
plt.figure(figsize=(10,10))
plt.plot(dates, frame["Model"], color="#ED3237")
plt.plot(dates, frame["BVSP"], color="#FEF0F0")
plt.title("Retorno da Estratégia")
plt.legend(["Model", "BVSP"])

# %%
60/121
# Out:
# 0.49586776859504134

# %%
frame["Model"].corr(frame["BVSP"], method='pearson')
# Out:
# -0.31622606736727304

# %%
Sharpe_Ratio = frame["Model"].mean() / frame["Model"].std()
Sharpe_Ratio
# Out:
# 0.11732994064856629

# %%
frame['cumluative_return'] = np.exp(np.log1p(new_frame['Model']).cumsum())
frame['cumluative_return_bvsp'] = np.exp(np.log1p(new_frame['BVSP']).cumsum())

# %%
frame
# Out:
#         Model      BVSP  cumluative_return  cumluative_return_bvsp
# 12        NaN  0.037066                NaN                1.037066
# 13        NaN -0.035623                NaN                1.000123
# 14        NaN  0.007132                NaN                1.007255
# 15        NaN  0.060496                NaN                1.068190
# 16        NaN -0.019540                NaN                1.047318
# ..        ...       ...                ...                     ...
# 115  0.191214  0.019377           1.373082                2.083630
# 116 -0.045005  0.061584           1.311287                2.211949
# 117  0.019536  0.004643           1.336904                2.222218
# 118  0.123612 -0.039439           1.502161                2.134575
# 119  0.095200 -0.024795           1.645167                2.081649
#
# [108 rows x 4 columns]
